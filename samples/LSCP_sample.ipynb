# %%
# !rm -f lscp-0.5-fa.7z
# !wget -O lscp-0.5-fa.7z https://lindat.mff.cuni.cz/repository/xmlui/bitstream/handle/11234/1-3195/lscp-0.5-fa.7z?sequence=1
# Out:
# 7[Files: 0  Bytes: 0  [0 B/s] Re]87[https://lindat.mff.cuni.cz/rep]87lscp-0.5-fa.7z       100% [=============================>]     145     --.-KB/s87HTTP response 302 Moved Temporarily [https://lindat.mff.cuni.cz/repository/xmlui/bitstream/handle/11234/1-3195/lscp-0.5-fa.7z?sequence=1]
# 87lscp-0.5-fa.7z       100% [=============================>]     145     --.-KB/s87Enqueue https://lindat.mff.cuni.cz/repository/bitstream/handle/11234/1-3195/lscp-0.5-fa.7z?sequence=1
# 87[https://lindat.mff.cuni.cz/rep]87[Files: 0  Bytes: 145  [381 B/s]87lscp-0.5-fa.7z       100% [=============================>]     131     --.-KB/s87HTTP response 302 Found [https://lindat.mff.cuni.cz/repository/bitstream/handle/11234/1-3195/lscp-0.5-fa.7z?sequence=1]
# 87lscp-0.5-fa.7z       100% [=============================>]     131     --.-KB/s87Enqueue https://lindat.mff.cuni.cz/repository/server/api/core/bitstreams/859f36bc-2fb8-4144-8985-fdaea34f0c7b/content
# 87[https://lindat.mff.cuni.cz/rep]87[Files: 0  Bytes: 276  [494 B/s]87Saving 'lscp-0.5-fa.7z'
# 87lscp-0.5-fa.7z         0% [>                             ]    2.99M    --.-KB/s87[Files: 0  Bytes: 276  [276 B/s]87lscp-0.5-fa.7z        10% [==>                           ]   40.03M   37.03MB/s87[Files: 0  Bytes: 276  [138 B/s]87lscp-0.5-fa.7z        26% [======>                       ]   99.98M   48.49MB/s87[Files: 0  Bytes: 276  [92 B/s]]87lscp-0.5-fa.7z        67% [===================>          ]  256.62M   84.51MB/s87[Files: 0  Bytes: 276  [68 B/s]]87[Files: 0  Bytes: 276  [55 B/s]]87lscp-0.5-fa.7z       100% [=============================>]  378.04M   93.73MB/s87[Files: 0  Bytes: 276  [45 B/s]]87lscp-0.5-fa.7z       100% [=============================>]  378.04M   93.73MB/s87HTTP response 200 Server: nginx/1.20.1 [https://lindat.mff.cuni.cz/repository/server/api/core/bitstreams/859f36bc-2fb8-4144-8985-fdaea34f0c7b/content]
# 87[Files: 1  Bytes: 378.04M [59.3]8

# %%
!7z e lscp-0.5-fa.7z
# Out:
# 7-Zip 25.01 (x64) : Copyright (c) 1999-2025 Igor Pavlov : 2025-08-03
#  64-bit locale=en_US.UTF-8 Threads:128 OPEN_MAX:524288
#
# Scanning the drive for archives:
#   0M Sca        1 file, 396407517 bytes (379 MiB)
#
# Extracting archive: lscp-0.5-fa.7z
# --
# Path = lscp-0.5-fa.7z
# Type = 7z
# Physical Size = 396407517
# Headers Size = 138
# Method = LZMA2:24
# Solid = -
# Blocks = 1
#
#          3   62% - lscp-0.5-fa.t                     76% - lscp-0.5-fa.t                     88% - lscp-0.5-fa.t                     97% - lscp-0.5-fa.t                     98% - lscp-0.5-fa.t                     99% - lscp-0.5-fa.t                    100% - lscp-0.5-fa.t                    100%    Everything is Ok
#
# Size:       2927042601
# Compressed: 396407517

# %%
#Open the file with read only permit
f = open('lscp-0.5-fa.txt', "r")
#Use readlines to read all lines in the file
#The variable "lines" is a list containing all lines in the file
lines = f.readlines()
#Close the file after reading the lines.
f.close()

# %%
#Select an example
example_text = lines[150]
print(example_text)
# Out:
# #حديثامام صادق علیه السلام:هرصنعتگرى براى جلب مشترى ناگزير ازداشتن سه خصلت است:۱↫ دركارش مهارت داشته باشد۲↫ دركارش امانتدارباشد۳↫ ورضايت خاطر كسى راكهبه اوسفارش كار داده است،بدست آورد.به نظر شما چند درصد از صنعتگران ما این سه صفات رو دارن؟!مخصوصا خودرو سازها...!
